# %%
import pandas as pd

song_list = pd.read_csv(r'./Dataset/top_song_2014_2024.csv')

song_list.head()
# Out:
#    year                      song          artist  play_count
# 0  2014         Thinking out Loud      Ed Sheeran         473
# 1  2014         Come Away With Me     Norah Jones         242
# 2  2014         Happy Little Pill     Troye Sivan         242
# 3  2014               Superheroes      The Script         232
# 4  2014  How Long Will I Love You  Ellie Goulding         189

# %%
song_list.columns
# Out:
# Index(['year', 'song', 'artist', 'play_count'], dtype='object')

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Authenticate with Spotify
client_id = 'your_client_id'
client_secret = 'your_client_secret'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get Spotify URL for a song and artist
def get_spotify_url(song, artist):
    query = f"track:{song} artist:{artist}"
    result = sp.search(query, limit=1, type='track')
    if result['tracks']['items']:
        return result['tracks']['items'][0]['external_urls']['spotify']
    else:
        return None  # If no result found

# Apply the function to each row in the dataframe and create a new column 'spotify_url'
song_list['spotify_url'] = song_list.apply(lambda row: get_spotify_url(row['song'], row['artist']), axis=1)

# Save the updated dataframe to the same CSV file (this will overwrite the existing file)
# song_list.to_csv('songs_url.csv', index=False)

# Show the updated dataframe (optional)
song_list.head()
# Out:
#    year                      song          artist  play_count  \
# 0  2014         Thinking out Loud      Ed Sheeran         473
# 1  2014         Come Away With Me     Norah Jones         242
# 2  2014         Happy Little Pill     Troye Sivan         242
# 3  2014               Superheroes      The Script         232
# 4  2014  How Long Will I Love You  Ellie Goulding         189
#
#                                          spotify_url
# 0  https://open.spotify.com/track/34gCuhDGsG4bRPI...
# 1  https://open.spotify.com/track/6jGnykaS6TkWp15...
# 2  https://open.spotify.com/track/4z8Ll8nU1jMqB8H...
# 3  https://open.spotify.com/track/37sINbJZcFdHFAs...
# 4  https://open.spotify.com/track/3X003bO0MMxXEsJ...

# %% [markdown]
# # Fetch song ID

# %%
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import os
from dotenv import load_dotenv

# Load environment variable
load_dotenv()

client_id = os.getenv('client_id')
client_secret = os.getenv('secret_id')

# Setup authentication manager
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Setup a Spotipy instance with the credential manager
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get song ID based on song name and artist
def get_song_id(song_name, artist_name):
    results = sp.search(q=f"track:{song_name} artist:{artist_name}", type='track', limit=1)
    
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        return track['id']
    else:
        return None

# Initialize lists to store data
song_names = []
artist_names = []
song_ids = []

# Loop through your DataFrame (song_list) and get song IDs
for _, row in song_list.iterrows():
    song_name = row['song']
    artist_name = row['artist']
    
    song_id = get_song_id(song_name, artist_name)
    
    # Append data to lists
    song_names.append(song_name)
    artist_names.append(artist_name)
    song_ids.append(song_id)
    
    if song_id:
        print(f"Song '{song_name}' by {artist_name} ID: {song_id}")
    else:
        print(f"Song '{song_name}' by {artist_name} not found on Spotify.")

# Create a DataFrame from the lists
df = pd.DataFrame({
    'song': song_names,
    'artist': artist_names,
    'song_id': song_ids
})

# Save the DataFrame to a CSV file
df.to_csv('spotify_song_ids.csv', index=False)

print("Song IDs saved to spotify_song_ids.csv")
# Out:
# Song 'Thinking out Loud' by Ed Sheeran ID: 34gCuhDGsG4bRPIf9bb02f
# Song 'Come Away With Me' by Norah Jones ID: 6jGnykaS6TkWp15utXSAeI
# Song 'Happy Little Pill' by Troye Sivan ID: 4z8Ll8nU1jMqB8HvKTyLP1
# Song 'Superheroes' by The Script ID: 37sINbJZcFdHFAsVNsPq1i
# Song 'How Long Will I Love You' by Ellie Goulding ID: 3X003bO0MMxXEsJJxidiig
# Song 'Try' by Colbie Caillat ID: 0dSchkfNB8SzYj8Bx7bcCW
# Song 'Chandelier' by Sia ID: 4VrWlk8IQxevMvERoX08iC
# Song 'Not a Bad Thing' by Justin Timberlake ID: 3nB82yGjtbQFSU0JLAwLRH
# Song 'You're So Fine' by Guba ID: 21cv4nfmZQ5UA7VFvTgXIg
# Song 'Cool Kids' by Echosmith ID: 13P5rwmk2EsoFRIz9UCeh9
# Song 'Rude' by MAGIC! ID: 6RtPijgfPKROxEzTHNRiDp
# Song 'Life's For The Living' by Passenger ID: 6o4i7cYPU9lZDbvjXKtR1W
# Song 'Young And Beautiful' by Lana Del Rey ID: 2nMeu6UenVvwUktBCpLMK9
# Song 'Musician' by Yuna ID: 5D3Mwo89ut2BYD4fT6WvAh
# Song 'Another Love' by Tom Odell ID: 3JvKfv6T31zO0ini8iNItO
# Song 'How Deep Is Your Love' by Bee Gees ID: 2JoZzpdeP2G6Csfdq5aLXP
# Song 'Thank You' by Dido ID: 09CnYHiZ5jGT1wr1TXJ9Zt
# Song 'Lost Stars' by Adam Levine ID: 1Duym1lVQurgKHHSqpOWhY
# Song 'Like I'm Gonna Lose You' by Meghan Trainor ID: 2YlZnw2ikdb837oKMKjBkW
# Song 'Take Me to Church' by Hozier ID: 3dYD57lRAUcMHufyqn9GcI
# Song 'Backpacking Around Europe' by Yuna ID: 4IR3YDt6XWuXQOE3Z9CPPb
# Song 'Cleanin' Out My Closet' by Eminem ID: 7BMO7O7ImjV8HNTH74Tshv
# Song 'Mad World' by Gary Jules ID: 3JOVTQ5h8HGFnDdp4VT3MP
# Song 'Somebody That I Used To Know' by Gotye ID: 1qDrWA6lyx8cLECdZE7TV7
# Song 'Imagine' by John Lennon ID: 7pKfPomDEeI4TPT6EOYjn9
# Song 'Habits (Stay High)' by Tove Lo ID: 18AJRdgUoO9EYn11N7xzaT
# Song 'Kiss Me' by Sixpence None The Richer ID: 754kgU5rWscRTfvlsuEwFp
# Song 'Lights And Camera' by Yuna ID: 4USgaSv1DqJby1iW6wVpeH
# Song 'After Midnight' by Yuna ID: 781eLoy8pVUCTNegU8gudf
# Song 'I Wanna Go' by Yuna ID: 0Ss4J4QHCkl0btHF5j9xvI
# Song 'Same Old Love' by Selena Gomez ID: 6ZANrVuAMp2rpjhfbOuJly
# Song 'Unapologetic Bitch' by Madonna ID: 4NXMr3Zbt4eAmgwyc3goLq
# Song 'Hymn for the Weekend' by Coldplay ID: 3RiPr603aXAoi4GHyXx0uy
# Song 'How Deep Is Your Love' by Bee Gees ID: 2JoZzpdeP2G6Csfdq5aLXP
# Song 'NO' by Meghan Trainor ID: 0l0CvurVUrr2w3Jj1hOVFc
# Song 'Flawless' by Beyoncé ID: 0zVMzJ37VQNFUNvdxxat2E
# Song 'Lost Stars' by Adam Levine ID: 1Duym1lVQurgKHHSqpOWhY
# Song 'Crush' by Yuna ID: 3Txcx4jhuiTZSvhAL0WaRc
# Song 'Send My Love' by Adele ID: 563SfWAHJs4FBZMkRN0IFN
# Song 'i hate u, i love u' by gnash ID: 7vRriwrloYVaoAe3a9wJHe
# Song 'Lost Boy' by Ruth B. ID: 0zMzyHAeMvwq5CRstru1Fp
# Song 'Cater 2 U' by Destiny's Child ID: 0FZvjrHpAmLKj574M4VwrF
# Song 'Too Close' by Yuna ID: 6M1VZfBisoKZDCzBIoGpFk
# Song 'Fuck You' by Lily Allen ID: 5st5644IlBmKiiRE73UsoZ
# Song '7/11' by Beyoncé ID: 02M6vucOvmRfMxTXDUwRXu
# Song 'Issues' by Julia Michaels ID: 7vu0JkJh0ldukEYbTVcqd0
# Song 'I Don't Wanna Live Forever' by ZAYN ID: 55n9yjI6qqXh5F2mYvUc2y
# Song 'Bad Things' by mgk ID: 1PSBzsahR2AKwLJgx8ehBj
# Song 'All Time Low' by Jon Bellion ID: 1CnPYaKxTVb4LWOtiGOm0m
# Song 'Pulang' by Yuna ID: 2FlD3k6jV8ylgvh1ocMHmB
# Song 'Come Away With Me' by Norah Jones ID: 6jGnykaS6TkWp15utXSAeI
# Song 'Shape of You' by Ed Sheeran ID: 7qiZfU4dY1lWllzX7mPBI3
# Song 'You're Not There' by Lukas Graham ID: 3cdmLOVYY9vht4a1THRJcZ
# Song 'Say You Won't Let Go' by James Arthur ID: 5uCax9HTNlzGybIStD3vDh
# Song 'Scars To Your Beautiful' by Alessia Cara ID: 0wI7QkCcs8FUQE1OkXUIqd
# Song 'Weak' by AJR ID: 3BuLtAmXKy5uQYl4ED1zBT
# Song 'Million Reasons' by Lady Gaga ID: 7dZ1Odmx9jWIweQSatnRqo
# Song 'Try' by Colbie Caillat ID: 0dSchkfNB8SzYj8Bx7bcCW
# Song 'Everyday' by Ariana Grande ID: 30TmLgK0ja5O8q9l4BShIX
# Song 'Empty' by Olivia O'Brien ID: 3ze5haYQIPLiNHq3Iahz98
# Song 'Let You Down' by NF ID: 52okn5MNA47tk87PeZJLEL
# Song 'Sorry Not Sorry' by Demi Lovato ID: 0yvPEnB032fojLfVluFjUv
# Song 'Meant to Be' by Bebe Rexha ID: 7iDa6hUg2VgEL1o1HjmfBn
# Song 'Somebody To Love' by Queen ID: 4rDbp1vnvEhieiccprPMdI
# Song 'Another One Bites The Dust' by Queen ID: 5vdp5UmvTsnMEMESIF2Ym7
# Song 'Stressed Out' by Twenty One Pilots ID: 3CRDbSIZ4r5MsZ0YwxuEkn
# Song 'Under Pressure' by Queen ID: 2fuCquhmrzHpu5xcA1ci9x
# Song 'Don't Stop Me Now' by Queen ID: 5T8EDUDqKcs6OSOwEsfqG7
# Song 'Bohemian Rhapsody' by Queen ID: 4u7EnebtmKWzUH433cf5Qv
# Song 'Most Girls' by Hailee Steinfeld ID: 10GJQkjRJcZhGTLagFOC62
# Song 'Praying' by Kesha ID: 0jdny0dhgjUwoIp5GkqEaA
# Song 'I Want To Break Free' by Queen ID: 7iAqvWLgZzXvH38lA06QZg
# Song 'Killer Queen' by Queen ID: 4cIPLtg1avt2Jm3ne9S1zy
# Song 'Crazy Little Thing Called Love' by Queen ID: 6xdLJrVj4vIXwhuG8TMopk
# Song 'Run the World (Girls)' by Beyoncé ID: 1uXbwHHfgsXcUKfSZw5ZJ0
# Song 'Anxiety' by Julia Michaels ID: 1XJ93XskwJf7PCyIVLbNBt
# Song '7 rings' by Ariana Grande ID: 6ocbgoVGwYJhOv1GgI9NsF
# Song 'Woke Up Late' by Drax Project ID: 4oPWkP9zQ5ANBbfdHGOvKF
# Song 'Lelaki' by Yuna ID: 60U4U6oeGKMHJDdUI4ko6L
# Song 'Never Seen the Rain' by Tones And I ID: 5zLnA9bO6QXc4AAvCriJfO
# Song 'Somebody To Love' by Queen ID: 4rDbp1vnvEhieiccprPMdI
# Song 'Work from Home' by Fifth Harmony ID: 4tCtwWceOPWzenK2HAIJSb
# Song 'Motivation' by Normani ID: 0rIAC4PXANcKmitJfoqmVm
# Song 'Mother's Daughter' by Miley Cyrus ID: 4tc97Wa8SP5f9gaaOar8Kq
# Song 'Layar Impian' by Ella ID: 0qd4BnhqqquTJlTnC4zMis
# Song 'If the World Was Ending' by JP Saxe ID: 2kJwzbxV2ppxnQoYw4GLBZ
# Song 'Take Me to Church' by Hozier ID: 3dYD57lRAUcMHufyqn9GcI
# Song 'Cater 2 U' by Destiny's Child ID: 0FZvjrHpAmLKj574M4VwrF
# Song 'Cleanin' Out My Closet' by Eminem ID: 7BMO7O7ImjV8HNTH74Tshv
# Song 'Patah Seribu' by Shila Amzah ID: 0Ni3RjjsQP0oz8lt8xsFIn
# Song 'Little Things' by Jessica Mauboy ID: 240WkSGaUBJMBmHLqS33WA
# Song 'Hey Ya!' by Outkast ID: 2PpruBYCo4H7WOBJ7Q2EwM
# Song 'If the World Was Ending' by JP Saxe ID: 2kJwzbxV2ppxnQoYw4GLBZ
# Song 'BROWN SKIN GIRL' by Blue Ivy ID: 0B3FovCVaGKS5w1FTidEUP
# Song 'Higher' by Rihanna ID: 1KnJwhZU3DIBe54Q4HPpIl
# Song 'Cinta Luar Biasa' by Andmesh ID: 4TPtPQIPMjWoRuZj4JLPDw
# Song 'Surrender' by Natalie Taylor ID: 0ecC8p17cDNlxHXkuYqeR6
# Song 'Cleanin' Out My Closet' by Eminem ID: 7BMO7O7ImjV8HNTH74Tshv
# Song 'Rare' by Selena Gomez ID: 7HMmFQsKsljwTw8bS7lu19
# Song 'Love On The Brain' by Rihanna ID: 5oO3drDxtziYU2H1X23ZIp
# Song 'Halo' by Beyoncé ID: 2CvOqDpQIMw69cCzWqr5yr
# Song 'Kiss It Better' by Rihanna ID: 0UHB9METy4VCXNgkcGqHqS
# Song 'Same Ol Mistakes' by Rihanna ID: 6RtzmszGXs32TRhv5zTKNM
# Song 'Needed Me' by Rihanna ID: 4pAl7FkDMNBsjykPXo91B3
# Song 'Close To You' by Rihanna ID: 6D2tzc8kRnZb7P1lNwMBLH
# Song 'Rain On Me' by Lady Gaga ID: 7ju97lgwC2rKQ6wwsf9no9
# Song 'Sorry Not Sorry' by Demi Lovato ID: 0yvPEnB032fojLfVluFjUv
# Song 'The Middle' by Zedd ID: 09IStsImFySgyp0pIQdqAc
# Song 'Love On Top' by Beyoncé ID: 1z6WtY7X4HQJvzxC4UgkSf
# Song 'Irreplaceable' by Beyoncé ID: 6RX5iL93VZ5fKmyvNXvF1r
# Song 'no tears left to cry' by Ariana Grande ID: 2qT1uLXPVPzGgFOx4jtEuo
# Song 'Never Really Over' by Katy Perry ID: 5PYQUBXc7NYeI1obMKSJK0
# Song '2002' by Anne-Marie ID: 2BgEsaKNfHUdlh97KmvFyo
# Song 'Don't Start Now' by Dua Lipa ID: 3PfIrDoz19wz7qK7tYeu62
# Song 'thank u, next' by Ariana Grande ID: 3e9HZxeyfWwjeyPAMmWSSQ
# Song 'Lonely' by Justin Bieber ID: 3S8jK1mGzQi24ilFb45DAZ
# Song 'Chi se ne frega' by Devis not found on Spotify.
# Song 'I Don't Care' by Ed Sheeran ID: 0hVXuCcriWRGvwMV1r5Yn9
# Song 'Dance for You' by Beyoncé ID: 7cvkXf3AwPGT041PyOi5VX
# Song 'Dancing With A Stranger' by Sam Smith ID: 3xgT3xIlFGqZjYW9QlhJWp
# Song 'Unholy' by Sam Smith ID: 0NZPBYD5qbEWRs3PrGiRkT
# Song 'Rembau Most Wanted' by W.A.R.I.S ID: 6ZzqQJEskolOcb312Jpx9S
# Song 'Bodak Yellow' by Cardi B ID: 6KBYefIoo7KydImq1uUQlL
# Song 'Calm Down' by Rema ID: 0WtM2NBVQNNJLh6scP13H8
# Song 'Until I Found You' by Stephen Sanchez ID: 6VhuP99TE6gYNQRJIlAWFD
# Song 'SWIPE' by ALYPH ID: 1FNfR4kZyozQ1unC5rQGC6
# Song 'RING RING' by Luqman Podolski ID: 4LnqpVgUfQO2uDRxCRysuS
# Song 'CUFF IT' by Beyoncé ID: 1xzi1Jcr7mEi9K2RfzLOqS
# Song 'Sorang' by Luqman Podolski ID: 2e3J1dAm54o9YcZVFo6nl8
# Song 'I Ain't Worried' by OneRepublic ID: 4h9wh7iOZ0GGn8QVp4RAOB
# Song 'Sedang Ingin Bercinta' by Dewa 19 ID: 44n4zJjacUQJSJncx0YW7h
# Song 'Fuck You' by Lily Allen ID: 5st5644IlBmKiiRE73UsoZ
# Song 'INDUSTRY BABY' by Lil Nas X ID: 27NovPIUIRrOZoCHxABJwK
# Song 'Super Freaky Girl' by Nicki Minaj ID: 4C6Uex2ILwJi9sZXRdmqXp
# Song 'Anti-Hero' by Taylor Swift ID: 0V3wPSX9ygBnCm8psDIegu
# Song 'Sial' by Mahalini ID: 6O0WEM0QNEhqpU50BKui7o
# Song 'La Vie En Rose' by Daniela Andrade ID: 0VxocBntP1XTZRsR9ZURPS
# Song 'Unchained Melody' by The Righteous Brothers ID: 2qhASBzpbFhPRtrnZ5lLnz
# Song 'Until I Found You' by Stephen Sanchez ID: 6VhuP99TE6gYNQRJIlAWFD
# Song 'Ke Hujung Dunia' by Sarah ID: 0UJPUgOBIQSiow82qd9awv
# Song 'Blue' by Aina Abdul ID: 0DeERXbSE5amnnFx5MSycO
# Song 'Heartbreak Anniversary' by Giveon ID: 3FAJ6O0NOHQV8Mc5Ri6ENp
# Song 'Malampagi' by Saixse ID: 6QV8eV3QVFp5upaTYjm7Xy
# Song 'Satu Malam Di Temasek' by Joe Flizzow ID: 5nsfVwWz1M1sug2ILCVygq
# Song 'Touch My Body' by Mariah Carey ID: 2aEuXA1KswHlCGPOuPmCOW
# Song 'Sakit' by Zynakal ID: 2rAJy2WSlQOINaWi0kydkr
# Song 'Hasrat' by Amir Jahari ID: 3Q6DYlT649Y1tgyf5We71c
# Song 'Another Love' by Tom Odell ID: 3JvKfv6T31zO0ini8iNItO
# Song 'Rich Flex' by Drake ID: 1bDbXMyjaUIooNwFE9wn0N
# Song 'Budapest' by George Ezra ID: 2ixsaeFioXJmMgkkbd4uj1
# Song 'Cinta Tak Pernah Tepat Waktu' by Aina Abdul ID: 5TFvDLLJZGgl4F9eJegCgd
# Song 'Nobody Gets Me' by SZA ID: 5Y35SjAfXjjG0sFQ3KOxmm
# Song 'redrum' by 21 Savage ID: 52eIcoLUM25zbQupAZYoFh
# Song 'TGIF' by GloRilla ID: 2hKYtHbwYOSjvYQhVdUpdQ
# Song 'Homecoming' by Kanye West ID: 4iz9lGMjU1lXS51oPmUmTe
# Song 'best side' by DOLLA ID: 3pbomh53cYaftJJ6x4n6UU
# Song 'Touch My Body' by Mariah Carey ID: 2aEuXA1KswHlCGPOuPmCOW
# Song 'Jiwa Yang Bersedih' by Ghea Indrawari ID: 6XsFgTG4dY768oIB4Dmeu0
# Song 'HIND'S HALL' by Macklemore ID: 1zOgXnODZUp87IGbF3b8YB
# Song 'Mamushi' by Megan Thee Stallion ID: 5b3XJ1pjrHO5JtY2PcTjnI
# Song 'Takkan Berpaling DariMu' by Rossa ID: 4L6lkjVqEg17sOmzhcK0F3
# Song 'Too Sweet' by Hozier ID: 19XpFsce28aByvCC4g89tJ
# Song 'Work Song' by Hozier ID: 35PKfoynRpVFoAUE3D5Kc6
# Song 'Players' by Coi Leray ID: 6UN73IYd0hZxLi8wFPMQij
# Song 'R.E.M' by Ariana Grande ID: 1xWH8zYtDeS9mW1JJG23VZ
# Song IDs saved to spotify_song_ids.csv

# %% [markdown]
# # fetch audio features using audio_features() method

# %%
import pandas as pd

spotify_song_id = pd.read_csv(r'./Dataset/spotify_song_ids.csv')

spotify_song_id.head()
# Out:
#                        song          artist                 song_id
# 0         Thinking out Loud      Ed Sheeran  34gCuhDGsG4bRPIf9bb02f
# 1         Come Away With Me     Norah Jones  6jGnykaS6TkWp15utXSAeI
# 2         Happy Little Pill     Troye Sivan  4z8Ll8nU1jMqB8HvKTyLP1
# 3               Superheroes      The Script  37sINbJZcFdHFAsVNsPq1i
# 4  How Long Will I Love You  Ellie Goulding  3X003bO0MMxXEsJJxidiig

# %%
spotify_song_id.columns
# Out:
# Index(['song', 'artist', 'song_id'], dtype='object')

# %%
import pandas as pd
import spotipy
import os
from dotenv import load_dotenv
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.exceptions import SpotifyException


# Load environment variable
load_dotenv()

client_id = os.getenv('client_id')
client_secret = os.getenv('secret_id')

# Setup authentication manager
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Setup a Spotipy instance with the credential manager
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# List of song IDs you want to check
spot_ids = ['34gCuhDGsG4bRPIf9bb02f', 'invalid_song_id', '6jGnykaS6TkWp15utXSAeI']

# Function to check if a song ID is valid
def is_valid_song_id(song_id):
    try:
        track = sp.track(song_id)  # Try to fetch the track
        print(f"Song ID {song_id} is valid. Track name: {track['name']}")
        return True
    except SpotifyException as e:
        if e.http_status == 404:
            print(f"Song ID {song_id} is invalid. Track not found.")
        else:
            print(f"Error fetching song ID {song_id}: {e}")
        return False

# Check if each song ID is valid
for song_id in spot_ids:
    is_valid_song_id(song_id)
# Out:
# Song ID 34gCuhDGsG4bRPIf9bb02f is valid. Track name: Thinking out Loud
# Error fetching song ID invalid_song_id: http status: 400, code:-1 - Unsupported URL / URI., reason: None
# Song ID 6jGnykaS6TkWp15utXSAeI is valid. Track name: Come Away With Me

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Fetch credentials
client_id = os.getenv('client_id')
client_secret = os.getenv('secret_id')
SPOTIFY_REDIRECT_URI = os.getenv('SPOTIFY_REDIRECT_URI')

# print(client_id, client_secret)
# print(SPOTIFY_REDIRECT_URI)
